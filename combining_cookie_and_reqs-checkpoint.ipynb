# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tldextract
# from util import misc as misc_util # just copied the helpers here
cookies = pd.read_csv('Data/cookies.csv')
kid_domain_cookies = pd.read_csv('Data/page_data_with_categories_by_meta_title_text.csv')

# %%
reqs = pd.read_csv('data/requests.csv')

# %%
kid_pages = pd.read_csv('Data/KidPages_ver1.csv')

# %% [markdown]
# ## Generalized Helper Functions

# %%
# Probaby it doesn't belong here
def show_dataframe(df, n_items):
    # Print
    print('\nCategory rows: %d' %df.shape[0])
    print('First few items: \n%s' %df.head(n_items))

# Return a subcategory
def get_category(df, category_id):
        return df[['start_url','category']][df['category'] == category_id]

# Some useful tools things.
def peek_categories(df, n_categories, n_items):

    for category in range(n_categories):
        show_dataframe(get_category(df, category), n_items)

# Getting domain from url
# Sometimes the domain is the 0th or 2nd position
def urlToDomain(urlValue):
    if len(urlValue)> 1:
        return tldextract.extract(urlValue).domain
    else:
        return urlValue


# Third party request
def isThirdParty(fromDomain, toDomain):
    return fromDomain != toDomain

## Count third party requests by domain
def countDomainwiseThirdParties(dataframe, normal=False):
    return dataframe[dataframe['third_party'] == True]['from'].value_counts(normalize=normal)

def countDomainwiseFirstParties(dataframe, normal=False):
    return dataframe[dataframe['third_party'] == False]['from'].value_counts(normalize=normal)

# Count third party from a DataFrame
# Return normalized values
def countThirdParties(dataframe, normal=True):
    return dataframe[dataframe['third_party'] == True]["to"].value_counts(normalize=normal)

# Returns a list of third parties
def countUniqueThirdParties(dataframe):
    return pd.unique(dataframe[['third_party', 'to']][dataframe['third_party'] == True]['to'])

# %%
## Decluttering a dataframe to have just what we want
## Do several things to reduce dimensions of the dataset to make it more interesting
## to analyze

## Annette -  added an is_reqs boolean because the column name varies for cookies and requests
def tinyfy(is_reqs, dataframe, return_columns = []):
    
    # Create a from and to column
    dataframe['from'] = dataframe['start_url'].apply(urlToDomain)
    if(is_reqs == True):
        dataframe['to'] = dataframe['request_domain'].apply(urlToDomain)
    else:
        dataframe['to'] = dataframe['cookie_domain'].apply(urlToDomain)

    # Adding third party columns for requests
    dataframe['third_party'] = isThirdParty(dataframe['from'], dataframe['to'])
    if len(return_columns) == 0:
        return dataframe
    else:
        return dataframe[return_columns]

# %%
# Dropping duplicates
# This is just a wrapper
def dropDuplicates(dataframe):
    return dataframe.drop_duplicates()


# Filter dataset by categories
def filterByCategories(dataset):
    return (dataset[dataset['category'] == 0], dataset[dataset['category'] == 1], dataset[dataset['category'] == 2], dataset[dataset['category'] == 3])


# Count stuff into first and third party
def toFirstAndThird(dataset):
    # Ugly stuff
    dataset['first_third'] =dataset.groupby(by=['from', 'third_party'])['from'].transform('count')
    first_third = dataset[['from', 'third_party', 'first_third']]
    first_third.drop_duplicates(inplace=True)

    first = first_third[first_third['third_party'] == False][['from', 'first_third']]
    third = first_third[first_third['third_party'] == True][['from','first_third']]

    first.rename(columns={'first_third': 'First party'}, inplace=True)
    first = first.merge(third)
    first.rename(columns={'first_third': 'Third party'}, inplace=True)

    return first

# %%
#Annette - New helper functions
# Return list of page_ids corresponding to children websites
kid_page_ids = kid_pages['Index'].to_list()
kid_page_ids.sort()
# surveys_df[surveys_df['page_id'].isin([kid_page_ids])]
def filter_kids(df, isReqs):
    if(isReqs):
        return df[df['page_id'].isin(kid_page_ids)]
    else:
        return df[df['page_id'].isin(kid_page_ids)]

# %%
kid_page_ids = kid_pages['Index'].to_list()
# kid_page_ids.sort()
kid_page_ids
x = [37]
# 37.isin([kid_page_ids])
reqs[reqs['page_id'].isin(kid_page_ids)]
# df[df['A'].isin([3, 6])]
# cookies.isin({'page_id': kid_page_ids})
# dd = DataFrame.Series()
# kid_page_ids
# cookies['page_id']
# Out:
#         page_id                                       start_url  \
# 237          37                 https://akidsbraintumorcure.org
# 239          37                 https://akidsbraintumorcure.org
# 241          37                 https://akidsbraintumorcure.org
# 242          37                 https://akidsbraintumorcure.org
# 243          37                 https://akidsbraintumorcure.org
# 244          37                 https://akidsbraintumorcure.org
# 245          37                 https://akidsbraintumorcure.org
# 246          37                 https://akidsbraintumorcure.org
# 247          37                 https://akidsbraintumorcure.org
# 248          37                 https://akidsbraintumorcure.org
# 249          37                 https://akidsbraintumorcure.org
# 250          37                 https://akidsbraintumorcure.org
# 251          37                 https://akidsbraintumorcure.org
# 252          37                 https://akidsbraintumorcure.org
# 253          37                 https://akidsbraintumorcure.org
# 6796        416               https://www.myteachingstation.com
# 6798        416               https://www.myteachingstation.com
# 6801        416               https://www.myteachingstation.com
# 6802        416               https://www.myteachingstation.com
# 6804        416               https://www.myteachingstation.com
# 6807        416               https://www.myteachingstation.com
# 6810        416               https://www.myteachingstation.com
# 6813        416               https://www.myteachingstation.com
# 6815        416               https://www.myteachingstation.com
# 6817        416               https://www.myteachingstation.com
# 6818        416               https://www.myteachingstation.com
# 6819        416               https://www.myteachingstation.com
# 6820        416               https://www.myteachingstation.com
# 6821        416               https://www.myteachingstation.com
# 6822        416               https://www.myteachingstation.com
# 6824        416               https://www.myteachingstation.com
# 6826        416               https://www.myteachingstation.com
# 6828        416               https://www.myteachingstation.com
# 15632       706             https://www.instituteforwriters.com
# 15638       706             https://www.instituteforwriters.com
# 15641       706             https://www.instituteforwriters.com
# 15644       706             https://www.instituteforwriters.com
# 15646       706             https://www.instituteforwriters.com
# 15649       706             https://www.instituteforwriters.com
# 15653       706             https://www.instituteforwriters.com
# 15658       706             https://www.instituteforwriters.com
# 15661       706             https://www.instituteforwriters.com
# 15663       706             https://www.instituteforwriters.com
# 15752       706             https://www.instituteforwriters.com
# 15753       706             https://www.instituteforwriters.com
# 15754       706             https://www.instituteforwriters.com
# 15755       706             https://www.instituteforwriters.com
# 15756       706             https://www.instituteforwriters.com
# 15757       706             https://www.instituteforwriters.com
# 15758       706             https://www.instituteforwriters.com
# 15759       706             https://www.instituteforwriters.com
# 15760       706             https://www.instituteforwriters.com
# 15761       706             https://www.instituteforwriters.com
# 15762       706             https://www.instituteforwriters.com
# 15763       706             https://www.instituteforwriters.com
# 15764       706             https://www.instituteforwriters.com
# 15765       706             https://www.instituteforwriters.com
# 15766       706             https://www.instituteforwriters.com
# 15767       706             https://www.instituteforwriters.com
# 15768       706             https://www.instituteforwriters.com
# 16530       709                      https://paradeorganics.com
# 16532       709                      https://paradeorganics.com
# 16535       709                      https://paradeorganics.com
# 16537       709                      https://paradeorganics.com
# 16541       709                      https://paradeorganics.com
# 16543       709                      https://paradeorganics.com
# 16545       709                      https://paradeorganics.com
# 16549       709                      https://paradeorganics.com
# 16552       709                      https://paradeorganics.com
# 16613       709                      https://paradeorganics.com
# 16614       709                      https://paradeorganics.com
# 16615       709                      https://paradeorganics.com
# 16616       709                      https://paradeorganics.com
# 16617       709                      https://paradeorganics.com
# 16618       709                      https://paradeorganics.com
# 16619       709                      https://paradeorganics.com
# 16620       709                      https://paradeorganics.com
# 16621       709                      https://paradeorganics.com
# 16622       709                      https://paradeorganics.com
# 18769       826                   https://www.youthdynamics.org
# 18771       826                   https://www.youthdynamics.org
# 18773       826                   https://www.youthdynamics.org
# 18776       826                   https://www.youthdynamics.org
# 18778       826                   https://www.youthdynamics.org
# 18781       826                   https://www.youthdynamics.org
# 18785       826                   https://www.youthdynamics.org
# 18788       826                   https://www.youthdynamics.org
# 18793       826                   https://www.youthdynamics.org
# 18797       826                   https://www.youthdynamics.org
# 18801       826                   https://www.youthdynamics.org
# 18804       826                   https://www.youthdynamics.org
# 18888       826                   https://www.youthdynamics.org
# 18889       826                   https://www.youthdynamics.org
# 18891       826                   https://www.youthdynamics.org
# 18894       826                   https://www.youthdynamics.org
# 18898       826                   https://www.youthdynamics.org
# 18902       826                   https://www.youthdynamics.org
# 18906       826                   https://www.youthdynamics.org
# 20500       920                       https://codewizardshq.com
# 20501       920                       https://codewizardshq.com
# 20502       920                       https://codewizardshq.com
# 20503       920                       https://codewizardshq.com
# 20504       920                       https://codewizardshq.com
# 20505       920                       https://codewizardshq.com
# 20506       920                       https://codewizardshq.com
# 20507       920                       https://codewizardshq.com
# 20508       920                       https://codewizardshq.com
# 20509       920                       https://codewizardshq.com
# 20510       920                       https://codewizardshq.com
# 20511       920                       https://codewizardshq.com
# 20512       920                       https://codewizardshq.com
# 20513       920                       https://codewizardshq.com
# 20514       920                       https://codewizardshq.com
# 20515       920                       https://codewizardshq.com
# 20516       920                       https://codewizardshq.com
# 20517       920                       https://codewizardshq.com
# 20518       920                       https://codewizardshq.com
# 20519       920                       https://codewizardshq.com
# 20520       920                       https://codewizardshq.com
# 20793       849                     https://www.monkeyhappy.com
# 20797       849                     https://www.monkeyhappy.com
# 20799       849                     https://www.monkeyhappy.com
# 20801       849                     https://www.monkeyhappy.com
# 20803       849                     https://www.monkeyhappy.com
# 20805       849                     https://www.monkeyhappy.com
# 20806       849                     https://www.monkeyhappy.com
# 20807       849                     https://www.monkeyhappy.com
# 20808       849                     https://www.monkeyhappy.com
# 20809       849                     https://www.monkeyhappy.com
# 20810       849                     https://www.monkeyhappy.com
# 20811       849                     https://www.monkeyhappy.com
# 20812       849                     https://www.monkeyhappy.com
# 20813       849                     https://www.monkeyhappy.com
# 20814       849                     https://www.monkeyhappy.com
# 20815       849                     https://www.monkeyhappy.com
# 22894      1019                https://stickyfingerscooking.com
# 22895      1019                https://stickyfingerscooking.com
# 22896      1019                https://stickyfingerscooking.com
# 22897      1019                https://stickyfingerscooking.com
# 22898      1019                https://stickyfingerscooking.com
# 22899      1019                https://stickyfingerscooking.com
# 22900      1019                https://stickyfingerscooking.com
# 23640      1023                       https://cssd.lacounty.gov
# 23642      1023                       https://cssd.lacounty.gov
# 23644      1023                       https://cssd.lacounty.gov
# 23647      1023                       https://cssd.lacounty.gov
# 23651      1023                       https://cssd.lacounty.gov
# 23654      1023                       https://cssd.lacounty.gov
# 23656      1023                       https://cssd.lacounty.gov
# 23658      1023                       https://cssd.lacounty.gov
# 23659      1023                       https://cssd.lacounty.gov
# 23661      1023                       https://cssd.lacounty.gov
# 23662      1023                       https://cssd.lacounty.gov
# 23663      1023                       https://cssd.lacounty.gov
# 33836      1281                        https://orangekidmin.com
# 33841      1281                        https://orangekidmin.com
# 33843      1281                        https://orangekidmin.com
# 33847      1281                        https://orangekidmin.com
# 33853      1281                        https://orangekidmin.com
# 33856      1281                        https://orangekidmin.com
# 33858      1281                        https://orangekidmin.com
# 33860      1281                        https://orangekidmin.com
# 33862      1281                        https://orangekidmin.com
# 33864      1281                        https://orangekidmin.com
# 33866      1281                        https://orangekidmin.com
# 33868      1281                        https://orangekidmin.com
# 33870      1281                        https://orangekidmin.com
# 33874      1281                        https://orangekidmin.com
# 33928      1281                        https://orangekidmin.com
# 33929      1281                        https://orangekidmin.com
# 33931      1281                        https://orangekidmin.com
# 33933      1281                        https://orangekidmin.com
# 33935      1281                        https://orangekidmin.com
# 33937      1281                        https://orangekidmin.com
# 33938      1281                        https://orangekidmin.com
# 33940      1281                        https://orangekidmin.com
# 34114      1258                              https://jaacap.org
# 34121      1258                              https://jaacap.org
# 34122      1258                              https://jaacap.org
# 34123      1258                              https://jaacap.org
# 34126      1258                              https://jaacap.org
# 34129      1258                              https://jaacap.org
# 34134      1258                              https://jaacap.org
# 34137      1258                              https://jaacap.org
# 34142      1258                              https://jaacap.org
# 34144      1258                              https://jaacap.org
# 34149      1258                              https://jaacap.org
# 34152      1258                              https://jaacap.org
# 34154      1258                              https://jaacap.org
# 34156      1258                              https://jaacap.org
# 34159      1258                              https://jaacap.org
# 34160      1258                              https://jaacap.org
# 34161      1258                              https://jaacap.org
# 34162      1258                              https://jaacap.org
# 34163      1258                              https://jaacap.org
# 34164      1258                              https://jaacap.org
# 34165      1258                              https://jaacap.org
# 34166      1258                              https://jaacap.org
# 34167      1258                              https://jaacap.org
# 34168      1258                              https://jaacap.org
# 34169      1258                              https://jaacap.org
# 34170      1258                              https://jaacap.org
# 34171      1258                              https://jaacap.org
# 34172      1258                              https://jaacap.org
# 34173      1258                              https://jaacap.org
# 34174      1258                              https://jaacap.org
# 34175      1258                              https://jaacap.org
# 34176      1258                              https://jaacap.org
# 34177      1258                              https://jaacap.org
# 34178      1258                              https://jaacap.org
# 34179      1258                              https://jaacap.org
# 34180      1258                              https://jaacap.org
# 34181      1258                              https://jaacap.org
# 34182      1258                              https://jaacap.org
# 34183      1258                              https://jaacap.org
# 34184      1258                              https://jaacap.org
# 34185      1258                              https://jaacap.org
# 65841      2358                            https://www.schuh.eu
# 65842      2358                            https://www.schuh.eu
# 65844      2358                            https://www.schuh.eu
# 65845      2358                            https://www.schuh.eu
# 65847      2358                            https://www.schuh.eu
# 65849      2358                            https://www.schuh.eu
# 65850      2358                            https://www.schuh.eu
# 65852      2358                            https://www.schuh.eu
# 65854      2358                            https://www.schuh.eu
# 65857      2358                            https://www.schuh.eu
# 65860      2358                            https://www.schuh.eu
# 65861      2358                            https://www.schuh.eu
# 65863      2358                            https://www.schuh.eu
# 65864      2358                            https://www.schuh.eu
# 65866      2358                            https://www.schuh.eu
# 65867      2358                            https://www.schuh.eu
# 65869      2358                            https://www.schuh.eu
# 65872      2358                            https://www.schuh.eu
# 65873      2358                            https://www.schuh.eu
# 71108      2595                       https://www.hyperlite.com
# 71109      2595                       https://www.hyperlite.com
# 71110      2595                       https://www.hyperlite.com
# 71111      2595                       https://www.hyperlite.com
# 71112      2595                       https://www.hyperlite.com
# 71113      2595                       https://www.hyperlite.com
# 71114      2595                       https://www.hyperlite.com
# 73151      2658                      https://www.hearthsong.com
# 73152      2658                      https://www.hearthsong.com
# 73155      2658                      https://www.hearthsong.com
# 73157      2658                      https://www.hearthsong.com
# 73160      2658                      https://www.hearthsong.com
# 73164      2658                      https://www.hearthsong.com
# 73176      2658                      https://www.hearthsong.com
# 73179      2658                      https://www.hearthsong.com
# 73180      2658                      https://www.hearthsong.com
# 73184      2658                      https://www.hearthsong.com
# 73186      2658                      https://www.hearthsong.com
# 74315      2658                      https://www.hearthsong.com
# 74316      2658                      https://www.hearthsong.com
# 74317      2658                      https://www.hearthsong.com
# 74318      2658                      https://www.hearthsong.com
# 74319      2658                      https://www.hearthsong.com
# 74320      2658                      https://www.hearthsong.com
# 74321      2658                      https://www.hearthsong.com
# ...
# 275754    parentingfromtheheartblog                     mfadsrvr         True
# 275755    parentingfromtheheartblog                     mfadsrvr         True
# 275756    parentingfromtheheartblog                  doubleclick         True
# 275757    parentingfromtheheartblog                        liadm         True
# 275758    parentingfromtheheartblog                       dotomi         True
# 275759    parentingfromtheheartblog                       fiftyt         True
# 275760    parentingfromtheheartblog                       fiftyt         True
# 275761    parentingfromtheheartblog                          ads         True
# 275762    parentingfromtheheartblog    parentingfromtheheartblog        False
# 275763    parentingfromtheheartblog                     pubmatic         True
# 275764    parentingfromtheheartblog                     pubmatic         True
# 275765    parentingfromtheheartblog                     pubmatic         True
# 275766    parentingfromtheheartblog                     pubmatic         True
# 275767    parentingfromtheheartblog                     mfadsrvr         True
# 275768    parentingfromtheheartblog                       pippio         True
# 275769    parentingfromtheheartblog                       pippio         True
# 275770    parentingfromtheheartblog                       pippio         True
# 275771    parentingfromtheheartblog                     pubmatic         True
# 275772    parentingfromtheheartblog                     pubmatic         True
# 275773    parentingfromtheheartblog                     pubmatic         True
# 276135    parentingfromtheheartblog                   onaudience         True
# 276136    parentingfromtheheartblog                   onaudience         True
# 276137    parentingfromtheheartblog                     pubmatic         True
# 276138    parentingfromtheheartblog                        apxlv         True
# 276139    parentingfromtheheartblog                          55c         True
# 276140    parentingfromtheheartblog                   onaudience         True
# 276141    parentingfromtheheartblog                     deviceid         True
# 276142    parentingfromtheheartblog                          55c         True
# 276143    parentingfromtheheartblog                    crwdcntrl         True
# 276144    parentingfromtheheartblog                    crwdcntrl         True
# 276145    parentingfromtheheartblog                     cogocast         True
# 276146    parentingfromtheheartblog                     cogocast         True
# 276147    parentingfromtheheartblog                   onaudience         True
# 276148    parentingfromtheheartblog                     cogocast         True
# 276149    parentingfromtheheartblog                          srv         True
# 276150    parentingfromtheheartblog                          srv         True
# 276151    parentingfromtheheartblog                          srv         True
# 276152    parentingfromtheheartblog                   contextweb         True
# 276153    parentingfromtheheartblog              technoratimedia         True
# 276154    parentingfromtheheartblog               betweendigital         True
# 276155    parentingfromtheheartblog               betweendigital         True
# 276156    parentingfromtheheartblog               betweendigital         True
# 276157    parentingfromtheheartblog               betweendigital         True
# 276158    parentingfromtheheartblog                          ads         True
# 276159    parentingfromtheheartblog                          ads         True
# 276160    parentingfromtheheartblog                          ads         True
# 276161    parentingfromtheheartblog                        yahoo         True
# 276162    parentingfromtheheartblog                         lkqd         True
# 276163    parentingfromtheheartblog                         lkqd         True
# 276164    parentingfromtheheartblog                         lkqd         True
# 276165    parentingfromtheheartblog                     exelator         True
# 276166    parentingfromtheheartblog                    infolinks         True
# 276167    parentingfromtheheartblog                    analytics         True
# 276168    parentingfromtheheartblog                     pubmatic         True
# 276169    parentingfromtheheartblog                         mgid         True
# 276170    parentingfromtheheartblog               altitude-arena         True
# 276171    parentingfromtheheartblog                      aniview         True
# 276172    parentingfromtheheartblog                      aniview         True
# 276173    parentingfromtheheartblog                         sync         True
# 276174    parentingfromtheheartblog                        tapad         True
# 276175    parentingfromtheheartblog                            c         True
# 276176    parentingfromtheheartblog                     servebom         True
# 276177    parentingfromtheheartblog                      taboola         True
# 276178    parentingfromtheheartblog                        lijit         True
# 276179    parentingfromtheheartblog               acuityplatform         True
# 276180    parentingfromtheheartblog                     clickagy         True
# 276691    parentingfromtheheartblog                         krxd         True
# 276692    parentingfromtheheartblog                        lijit         True
# 276693    parentingfromtheheartblog                        lijit         True
# 276694    parentingfromtheheartblog                        lijit         True
# 276695    parentingfromtheheartblog                        lijit         True
# 276696    parentingfromtheheartblog                        lijit         True
# 276697    parentingfromtheheartblog                        lijit         True
# 276698    parentingfromtheheartblog                     intentiq         True
# 276699    parentingfromtheheartblog                     intentiq         True
# 276700    parentingfromtheheartblog                     intentiq         True
# 276701    parentingfromtheheartblog                        lijit         True
# 276702    parentingfromtheheartblog                         agkn         True
# 276703    parentingfromtheheartblog                        lijit         True
# 276704    parentingfromtheheartblog                        lijit         True
# 276705    parentingfromtheheartblog                        lijit         True
# 276706    parentingfromtheheartblog                        lijit         True
# 276707    parentingfromtheheartblog                        lijit         True
# 276708    parentingfromtheheartblog                        lijit         True
# 276709    parentingfromtheheartblog                       pippio         True
# 276710    parentingfromtheheartblog                       rfihub         True
# 276711    parentingfromtheheartblog                        lijit         True
# 276712    parentingfromtheheartblog                        media         True
# 276713    parentingfromtheheartblog                        media         True
# 276714    parentingfromtheheartblog                        lijit         True
# 276715    parentingfromtheheartblog                        lijit         True
# 276716    parentingfromtheheartblog                       smadex         True
# 276717    parentingfromtheheartblog                     pubmatic         True
# 276718    parentingfromtheheartblog                     pubmatic         True
# 276719    parentingfromtheheartblog                        lijit         True
# 276720    parentingfromtheheartblog                      mxptint         True
# 276721    parentingfromtheheartblog                        sync1         True
# 276722    parentingfromtheheartblog                     intentiq         True
# 276723    parentingfromtheheartblog                     intentiq         True
# 276724    parentingfromtheheartblog                     intentiq         True
# 276725    parentingfromtheheartblog               rubiconproject         True
# 276726    parentingfromtheheartblog                     pubmatic         True
# 276727    parentingfromtheheartblog                          55c         True
# 276728    parentingfromtheheartblog               acuityplatform         True
# 276729    parentingfromtheheartblog                      owneriq         True
# 276730    parentingfromtheheartblog                      owneriq         True
# 276731    parentingfromtheheartblog                   quantserve         True
# 276732    parentingfromtheheartblog                  postrelease         True
# 276733    parentingfromtheheartblog                  postrelease         True
# 276734    parentingfromtheheartblog                        lijit         True
# 276735    parentingfromtheheartblog                     pubmatic         True
# 276736    parentingfromtheheartblog                     pubmatic         True
# 276737    parentingfromtheheartblog                        lijit         True
# 276738    parentingfromtheheartblog                        lijit         True
# 277078    parentingfromtheheartblog                    sitescout         True
# 277079    parentingfromtheheartblog                        rlcdn         True
# 277080    parentingfromtheheartblog                        adgrx         True
# 277081    parentingfromtheheartblog                     pubmatic         True
# 277082    parentingfromtheheartblog                     pubmatic         True
# 277083    parentingfromtheheartblog                          cpx         True
# 277084    parentingfromtheheartblog                          cpx         True
# 277085    parentingfromtheheartblog                          1rx         True
# 277086    parentingfromtheheartblog                        adgrx         True
# 277087    parentingfromtheheartblog                    eyereturn         True
# 277088    parentingfromtheheartblog              technoratimedia         True
# 277089    parentingfromtheheartblog                     pubmatic         True
# 277090    parentingfromtheheartblog                     pubmatic         True
# 277091    parentingfromtheheartblog                     pubmatic         True
# 277092    parentingfromtheheartblog                     pubmatic         True
# 277093    parentingfromtheheartblog                     pubmatic         True
# 277094    parentingfromtheheartblog                          ads         True
# 277095    parentingfromtheheartblog                          ads         True
# 277096    parentingfromtheheartblog                     pubmatic         True
# 277097    parentingfromtheheartblog                     pubmatic         True
# 277098    parentingfromtheheartblog                     pubmatic         True
# 277099    parentingfromtheheartblog                     pubmatic         True
# 277100    parentingfromtheheartblog                 tribalfusion         True
# 277101    parentingfromtheheartblog                     pubmatic         True
# 277102    parentingfromtheheartblog                        adsby         True
# 277103    parentingfromtheheartblog                        rlcdn         True
# 277104    parentingfromtheheartblog                          ads         True
# 277105    parentingfromtheheartblog                       adsrvr         True
# 277106    parentingfromtheheartblog                            c         True
# 277107    parentingfromtheheartblog                         bing         True
# 277108    parentingfromtheheartblog                            c         True
# 277109    parentingfromtheheartblog                     pubmatic         True
# 277110    parentingfromtheheartblog                     pubmatic         True
# 277111    parentingfromtheheartblog                          ads         True
# 277112    parentingfromtheheartblog                        aorta         True
# 277113    parentingfromtheheartblog                     pubmatic         True
# 277114    parentingfromtheheartblog                        lijit         True
# 277115    parentingfromtheheartblog                        lijit         True
# 277116    parentingfromtheheartblog                       zeotap         True
# 277457    parentingfromtheheartblog                         bidr         True
# 277458    parentingfromtheheartblog                         bidr         True
# 277459    parentingfromtheheartblog                smartadserver         True
# 277460    parentingfromtheheartblog                smartadserver         True
# 277461    parentingfromtheheartblog                smartadserver         True
# 277462    parentingfromtheheartblog             creative-serving         True
# 277463    parentingfromtheheartblog             creative-serving         True
# 277464    parentingfromtheheartblog             creative-serving         True
# 277465    parentingfromtheheartblog               fidelity-media         True
# 277466    parentingfromtheheartblog               fidelity-media         True
# 277467    parentingfromtheheartblog                      ctnsnet         True
# 277468    parentingfromtheheartblog                       dyntrk         True
# 277469    parentingfromtheheartblog                  casalemedia         True
# 277470    parentingfromtheheartblog                  casalemedia         True
# 277471    parentingfromtheheartblog                     udmserve         True
# 277472    parentingfromtheheartblog                     udmserve         True
# 277473    parentingfromtheheartblog                     udmserve         True
# 277474    parentingfromtheheartblog                      owneriq         True
# 277475    parentingfromtheheartblog                      owneriq         True
# 277476    parentingfromtheheartblog                           go         True
# 277477    parentingfromtheheartblog                           go         True
# 277478    parentingfromtheheartblog                           go         True
# 277479    parentingfromtheheartblog                           go         True
# 277480    parentingfromtheheartblog                  spotxchange         True
# 277481    parentingfromtheheartblog    parentingfromtheheartblog        False
# 277482    parentingfromtheheartblog                       demdex         True
# 277483    parentingfromtheheartblog                      mookie1         True
# 277484    parentingfromtheheartblog                      mookie1         True
# 277485    parentingfromtheheartblog                      mookie1         True
# 277486    parentingfromtheheartblog                          dpm         True
# 277487    parentingfromtheheartblog                        lijit         True
# 277488    parentingfromtheheartblog                    crwdcntrl         True
# 277489    parentingfromtheheartblog                    crwdcntrl         True
# 277490    parentingfromtheheartblog                     alphonso         True
# 277491    parentingfromtheheartblog                   contextweb         True
# 277492    parentingfromtheheartblog                     pubmatic         True
# 277493    parentingfromtheheartblog                       eyeota         True
# 277494    parentingfromtheheartblog                     mfadsrvr         True
# 277495    parentingfromtheheartblog                         agkn         True
# 277496    parentingfromtheheartblog                        lijit         True
# 277497    parentingfromtheheartblog                         sync         True
# 277498    parentingfromtheheartblog                     intentiq         True
# 277499    parentingfromtheheartblog                     intentiq         True
# 277500    parentingfromtheheartblog                        openx         True
# 277501    parentingfromtheheartblog                       eyeota         True
# 277502    parentingfromtheheartblog                       rfihub         True
# 277503    parentingfromtheheartblog                       rfihub         True

# %%
#Annette - new helper
#percent of total that have cookies or requests. both first and third parties
def percentTracking(total, df):
    num_first = countDomainwiseFirstParties(df).size
    num_third = countDomainwiseThirdParties(df).size
    percent_first = (num_first/total)*100
    percent_third = (num_third/total)*100
    return percent_first, percent_third

# %%
return df.loc[df['title'].str.contains("kid|child"), ['page_id', 'start_url', 'request_domain']]

# %% [markdown]
# # Analysis

# %%
#tinyfy

#reqs
get_columns = ['page_id', 'from', 'to', 'third_party']
small_req = tinyfy(True,reqs, get_columns)

#cookies
small_cookie = tinyfy(False,cookies, get_columns)

# %%
#count third parties
print(countUniqueThirdParties(small_req).size)
print(countUniqueThirdParties(small_cookie).size)
# Out:
# 6783
# 1197

# %%
# Dropping duplicates
small_req = dropDuplicates(small_req)
small_cookie = dropDuplicates(small_cookie)

# %%
count_third_party_requests.sort_values(ascending=True).plot.barh(figsize=(15, 15), title='Percentage of total', xlabel='Domain', grid=True)

# %%
count_third_party_cookies.sort_values(ascending=True).plot.barh(figsize=(15, 15), title='Percentage of total', xlabel='Domain', grid=True)

# %% [markdown]
# # Include Kid Cookies/Reqs

# %%
kid_cookies= filter_kids(cookies, False)
kid_reqs = filter_kids(reqs, True)

# %%
print(len(kid_reqs['page_id'].unique()))
# Out:
# 77

# %%
#make the dataframe for small_kid_cookie and small_kid_reqs
columns = ['page_id', 'from', 'to', 'third_party']
small_kid_cookie = tinyfy(False, kid_cookies, columns)
small_kid_reqs = tinyfy(True, kid_reqs, columns)
#need to drop duplicates here??
small_kid_cookie = dropDuplicates(small_kid_cookie)
small_kid_reqs = dropDuplicates(small_kid_reqs)
# Out:
# C:\Users\Annette\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Annette\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\Annette\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\Annette\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
total_orig = 10000
total_kid = len(kid_pages)
orig_cookies_first, orig_cookies_third = percentTracking(total_orig, small_cookie)
kid_cookies_first, kid_cookies_third = percentTracking(total_kid, small_kid_cookie)
orig_reqs_first, orig_reqs_third = percentTracking(total_orig, small_req)
kid_reqs_first, kid_reqs_third = percentTracking(total_kid, small_kid_reqs)

# %%
kid = [kid_cookies_first, kid_cookies_third, kid_reqs_first, kid_reqs_third]
orig = [orig_cookies_first, orig_cookies_third, orig_reqs_first, orig_reqs_third]
index = ['1P Cookies', '3P Cookies', '1P Requests', '3P Requests']
df = pd.DataFrame({'Children Sites ': kid,
                   'General Sites': orig}, index=index)
ax = df.plot.bar(rot=0, title = "Percent of Children's Websites vs General Websites with Cookies/Requests")

# %%
#value counts for the websites that have third parties
count_third_party_requests = countDomainwiseThirdParties(small_req) 
count_third_party_cookies = countDomainwiseThirdParties(small_cookie) 
count_third_party_requests_kid = countDomainwiseThirdParties(small_kid_reqs) 
count_third_party_cookies_kid = countDomainwiseThirdParties(small_kid_cookie)

#including 1st party now -- didnt make a difference in the graphs
count_requests = small_req['from'].value_counts() 
count_cookies = small_cookie['from'].value_counts()
count_requests_kid = small_kid_reqs['from'].value_counts() 
count_cookies_kid = small_kid_cookie['from'].value_counts()

# Top 10 domains
r_top10 = countThirdParties(small_req).sort_values(ascending=False)[:10]
c_top10 = countThirdParties(small_cookie).sort_values(ascending=False)[:10]
r_top10_kid = countThirdParties(small_kid_reqs).sort_values(ascending=False)[:10]
c_top10_kid = countThirdParties(small_kid_cookie).sort_values(ascending=False)[:10]

# %%
r_top10.index
# Out:
# Index(['fandom', 'wordpress', 'blogspot', 'gamepedia', 'softonic', 'iheart',
#        'tumblr', 'radio', 'yucatan', 'lankadeepa'],
#       dtype='object')

# %%
# Comparing most prevalent third parties 
from pandas import DataFrame
# print(third_party_count)
Data = {'Top Cookies- Normal': c_top10.index,
        'Top Cookies- Kid': c_top10_kid.index,
        'Top Requests- Normal': r_top10.index,
        'Top Requests- Kid': r_top10_kid.index
       }

df = DataFrame(Data,columns=['Top Cookies- Normal','Top Cookies- Kid', 'Top Requests- Normal', 'Top Requests- Kid'])
# df.plot(x ='Top Third Parties', y='Top Third Parties: Kids', kind = 'bar')
from IPython.display import HTML
HTML(df.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top Cookies- Normal</th>
#       <th>Top Cookies- Kid</th>
#       <th>Top Requests- Normal</th>
#       <th>Top Requests- Kid</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>doubleclick</td>
#       <td>doubleclick</td>
#       <td>google-analytics</td>
#       <td>google-analytics</td>
#     </tr>
#     <tr>
#       <td>facebook</td>
#       <td>facebook</td>
#       <td>googleapis</td>
#       <td>googleapis</td>
#     </tr>
#     <tr>
#       <td>rlcdn</td>
#       <td>adsrvr</td>
#       <td>gstatic</td>
#       <td>gstatic</td>
#     </tr>
#     <tr>
#       <td>youtube</td>
#       <td>casalemedia</td>
#       <td>doubleclick</td>
#       <td>doubleclick</td>
#     </tr>
#     <tr>
#       <td>yahoo</td>
#       <td>yahoo</td>
#       <td>google</td>
#       <td>google</td>
#     </tr>
#     <tr>
#       <td>pubmatic</td>
#       <td>bluekai</td>
#       <td>googletagmanager</td>
#       <td>facebook</td>
#     </tr>
#     <tr>
#       <td>openx</td>
#       <td>rlcdn</td>
#       <td>facebook</td>
#       <td>googletagmanager</td>
#     </tr>
#     <tr>
#       <td>adsrvr</td>
#       <td>openx</td>
#       <td>googleadservices</td>
#       <td>adnxs</td>
#     </tr>
#     <tr>
#       <td>casalemedia</td>
#       <td>advertising</td>
#       <td>cloudflare</td>
#       <td>googleadservices</td>
#     </tr>
#     <tr>
#       <td>advertising</td>
#       <td>agkn</td>
#       <td>googlesyndication</td>
#       <td>googlesyndication</td>
#     </tr>
#   </tbody>
# </table>

# %%
#1st party comparison
kid = [count_requests_kid.median(), count_cookies_kid.median()]
orig = [count_requests.median(), count_cookies.median()]
index = ['Median Requests', 'Median Cookies']
df = pd.DataFrame({'Children Sites ': kid,
                   'General Sites': orig}, index=index)
ax = df.plot.bar(rot=0, title = "Median 1st Party Requests/Cookies on Children vs General Websites")

# %%
#1st party comparison - MEAN
kid = [count_requests_kid.mean(), count_cookies_kid.mean()]
orig = [count_requests.mean(), count_cookies.mean()]
index = ['Median Requests', 'Median Cookies']
df = pd.DataFrame({'Children Sites ': kid,
                   'General Sites': orig}, index=index)
ax = df.plot.bar(rot=0, title = "Mean 1st Party Requests/Cookies on Children vs General Websites")

# %%
kid = [count_third_party_requests_kid.median(), count_third_party_cookies_kid.median()]
orig = [count_third_party_requests.median(), count_third_party_cookies.median()]
index = ['Median Requests', 'Median Cookies']
df = pd.DataFrame({'Children Sites ': kid,
                   'General Sites': orig}, index=index)
ax = df.plot.bar(rot=0, title = "Median Requests/Cookies on Children vs General Websites")

# %%
kid = [count_third_party_requests_kid.mean(), count_third_party_cookies_kid.mean()]
orig = [count_third_party_requests.mean(), count_third_party_cookies.mean()]
index = ['Mean Requests', 'Mean Cookies']
df = pd.DataFrame({'Children Sites ': kid,
                   'General Sites': orig}, index=index)
ax = df.plot.bar(rot=0, title = "Mean Requests/Cookies on Children vs General Websites")
